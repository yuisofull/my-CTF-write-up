# %%
import itertools

def small_roots(f, bounds, m=1, d=None):
	if not d:
		d = f.degree()

	if isinstance(f, Polynomial):
		x, = polygens(f.base_ring(), f.variable_name(), 1)
		f = f(x)

	R = f.base_ring()
	N = R.cardinality()
	
	f /= f.coefficients().pop(0)
	f = f.change_ring(ZZ)

	G = Sequence([], f.parent())
	for i in range(m+1):
		base = N^(m-i) * f^i
		for shifts in itertools.product(range(d), repeat=f.nvariables()):
			g = base * prod(map(power, f.variables(), shifts))
			G.append(g)

	B, monomials = G.coefficient_matrix()
	monomials = vector(monomials)

	factors = [monomial(*bounds) for monomial in monomials]
	for i, factor in enumerate(factors):
		B.rescale_col(i, factor)

	B = B.dense_matrix().LLL()

	B = B.change_ring(QQ)
	for i, factor in enumerate(factors):
		B.rescale_col(i, 1/factor)

	H = Sequence([], f.parent().change_ring(QQ))
	for h in filter(None, B*monomials):
		H.append(h)
		I = H.ideal()
		if I.dimension() == -1:
			H.pop()
		elif I.dimension() == 0:
			roots = []
			for root in I.variety(ring=ZZ):
				root = tuple(R(root[var]) for var in f.variables())
				roots.append(root)
			return roots

	return []

# %%
Ns = [..., ..., ..., ...]
cts = [..., ..., ..., ...]

# %%
from sage.all import *
from Crypto.Util.number import inverse, long_to_bytes

# # Replace these lists with the actual values from "output.txt"
# Ns = [
#     # Paste the Ns from output.txt here
# ]

# cts = [
#     # Paste the cts from output.txt here
# ]

e = 65537
n = len(Ns)

# Step 2: Construct the lattice
M = 2 ** 256  # Upper bound for r_i (256 bits)
dim = n + 1  # Dimension of the lattice

# Initialize the matrix
B = Matrix(ZZ, dim, dim)
B[0, 0] = M
for i in range(1, dim):
    B[i, 0] = Ns[i - 1]
    B[i, i] = -1

# Step 3: Apply LLL reduction
B_red = B.LLL()

# Step 4: Recover p and q_i
# The first row of B_red should contain the potential p and q_i coefficients
v = B_red[0]
potential_p = abs(v[0])
k_values = [-v[i] for i in range(1, dim)]

# Verify p and compute residuals
residuals = []
verified = True
for i in range(n):
    residual = Ns[i] - potential_p * k_values[i]
    residuals.append(residual)
    if abs(residual) >= M:
        print(f"Residual too large for N_{i}")
        verified = False

if verified:
    print(f"Recovered p: {potential_p}")

    # Step 5: Compute private exponents d_i
    ds = []
    for i in range(n):
        q_i = k_values[i]
        phi = (potential_p - 1) * (q_i - 1)
        try:
            d = inverse(e, phi)
        except ValueError:
            print(f"Failed to compute inverse for N_{i}")
            continue
        ds.append(d)

    # Step 6: Decrypt the ciphertexts
    for i in range(n):
        if i >= len(ds):
            continue
        m_int = pow(cts[i], ds[i], Ns[i])
        m_bytes = long_to_bytes(m_int)
        if b'flag' in m_bytes:
            print("Recovered flag:")
            print(m_bytes.strip(b'\x00'))
            break
else:
    print("Failed to verify potential p.")
# Out:
# Residual too large for N_0
# Residual too large for N_1
# Residual too large for N_2
# Residual too large for N_3
# Failed to verify potential p.

# %%
# p*q1 + a= N1=>N1 >> 256 = p*q1>>256
# p*q2 + b= N2
# p*q3 + c= N3
# p*q4 + d= N4

pbar=int(sqrt((n*a)//b))
lbits=500
ln = 2^lbits
p_length=1042
q_length=1044
p_high=pbar//ln

p0=p_high

# Recovery starts here
q0 = floor(n / (p0*ln))//ln
print("q0 bit lengths: ", len(bin(q0))-2)
X = Y = 2^(lbits+2) # bounds on x0 and y0


bounds = (X,Y)
R = Integers(n)
PR.<x, y> = PolynomialRing(Zmod(n))

f = (x+p0*ln)*(y+q0*ln)

r=small_roots(f, bounds)
if r == []:
    lbits = lbits + 1
print(small_roots(f, bounds))

print("p = ", p0*ln+r[0][0])

# %%
Ns = [..., ..., ..., ...]

# %%
print(len(bin(Ns[0])))

# %%
# Ensure you run this script in a SageMath environment

from sage.all import *

Ns = [
    ...,
    ...,
    ...,
    ...
]

cts = [
    ...,
    ...,
    ...,
    ...
]

e = 65537


def recover_p(Ns):
    PR = PolynomialRing(Zmod(Ns[0]), names=('x',)); (x,) = PR._first_ngens(1)
    diffs = [Ns[i] - Ns[0] for i in range(1, len(Ns))]
    equations = [x * (Ns[i] - Ns[0]) % Ns[i] for i in range(1, len(Ns))]
    modulus = Ns[0]

    M = Matrix(ZZ, len(diffs) + 1)
    for i in range(len(diffs)):
        M[i, i] = Ns[i + 1]
        M[i, -1] = -diffs[i]
    M[-1, -1] = modulus

    M = M.LLL()

    possible_p = abs(M[0, -1])
    if possible_p.bit_length() == 1024:
        return possible_p
    else:
        return None

p = recover_p(Ns)
if p is None:
    print("Failed to recover p.")
    exit()

print(f"Recovered p: {p}")

# Recover q_i and decrypt the flag
from Crypto.Util.number import inverse, long_to_bytes

flag = None
for i in range(len(Ns)):
    N = Ns[i]
    c = cts[i]
    q = N // p
    phi = (p - 1) * (q - 1)
    try:
        d = inverse(e, phi)
    except ValueError:
        continue
    m = pow(c, d, N)
    flag_bytes = long_to_bytes(m)
    if b'flag' in flag_bytes:
        flag = flag_bytes
        break

if flag:
    print(f"Recovered flag: {flag}")
else:
    print("Failed to recover the flag.")
# Out:
# Failed to recover p.
# Recovered p: None
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 52
#      49 print(f"Recovered p: {p}")
#      51 # Recover q_i and decrypt the flag
# ---> 52 from Crypto.Util.number import inverse, long_to_bytes
#      54 flag = None
#      55 for i in range(len(Ns)):
#
# ModuleNotFoundError: No module named 'Crypto'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from hashlib import sha256
from sage.all import *
from Crypto.Cipher import AES
from Crypto.Util.Padding import unpad

# Parameters
n = 100
m = 100
q = 7
FF = GF(q)

# Given seed
seed = [6, 80, 158, 13, 171, 216, 164, 5, 73, 233, 6, 213, 63, 162, 90, 63, 208, 245, 101, 11, 120, 95, 78, 145, 159, 108, 105, 252, 241, 124, 92, 120, 18, 177, 243, 237, 132, 103, 237, 11, 75, 141, 172, 208, 155, 47, 111, 59, 118, 209, 169, 81, 141, 236, 104, 131, 104, 194, 246, 232, 14, 246, 68, 172]
gen_seed = bytes(seed)

# Reconstruct F
F = []
for i in range(m):
    cur = []
    for j in range(n):
        cur.append([])
        for k in range(n):
            cur[-1].append(sha256(gen_seed).digest()[0] % q)
            gen_seed = sha256(gen_seed).digest()
    F.append(matrix(FF, n, n, cur))

# Given data
, 0, 0, 6, 2, 1, 6], [6, 2, 3, 0, 3, 3, 3, 0, 5, 3, 1, 5, 0, 2, 3, 0, 2, 2, 5, 5, 6, 5, 1, 3, 4, 2, 0, 2, 3, 4, 1, 0, 3, 2, 4, 5, 3, 4, 2, 6, 6, 1, 2, 4, 5, 3, 1, 4, 3, 4, 5, 1, 3, 4, 5, 1, 1, 6, 6, 1, 0, 1, 5, 3, 3, 4, 5, 4, 0, 5, 6, 4, 4, 0, 2, 5, 5, 2, 1, 4, 6, 3, 3, 3, 2, 5, 1, 6, 5, 3, 1, 4, 6, 3, 1, 2, 5, 1, 5, 1], [6, 1, 5, 3, 2, 3, 5, 3, 5, 2, 1, 0, 1, 2, 2, 4, 4, 1, 6, 2, 5, 0, 6, 4, 6, 5, 6, 0, 6, 5, 4, 4, 5, 4, 3, 1, 1, 1, 0, 2, 3, 0, 6, 2, 4, 0, 6, 1, 6, 5, 5, 2, 6, 3, 4, 2, 5, 0, 5, 5, 5, 0, 6, 3, 3, 2, 5, 1, 1, 4, 4, 1, 5, 1, 6, 0, 5, 3, 6, 4, 2, 1, 0, 0, 4, 2, 3, 5, 3, 5, 1, 3, 5, 3, 5, 6, 4, 0, 0, 4]]

# Function to compute a_i
def compute_a_i(com_i, v, verif_i):
    data = [int(x) for x in com_i + list(v) + verif_i]
    hash_digest = sha256(bytes(data)).digest()
    a_i = hash_digest[0] % q
    return a_i

# Compute a_list
a_list = []
for i in range(9):
    a_i = compute_a_i(coms[i], v, verifs[i])
    a_list.append(a_i)

# Set up the linear system A * s = b
A_rows = []
b_entries = []

for i in range(9):
    a_i = a_list[i]
    tass_i = vector(FF, tass[i])
    for j in range(m):
        F_j = F[j]
        com_ij = FF(coms[i][j])
        v_j = v[j]
        # Compute RHS
        RHS_ij = com_ij - a_i^2 * v_j - tass_i * F_j * tass_i
        # Compute coefficients
        coeff_ij = Matrix([Integer(2) * a_i * F_j * tass_i]).transpose()
        A_rows.append(coeff_ij)
        b_entries.append(RHS_ij)

# Build matrix A and vector b
A = matrix(FF, A_rows)
b = vector(FF, b_entries)

# Solve the system for s
s_solution = A.solve_right(b)

# Verify the solution
def apply1(F, v):
    out = []
    for i in range(m):
        out.append((v.transpose() * F[i] * v)[0, 0])
    return vector(FF, out)

s = vector(FF, s_solution)
v_check = apply1(F, s)
assert v_check == v, "Recovered s does not satisfy the given v."

# Given ciphertext and IV
ct = b'\xf7\xfd\thn\xc0="\xed\x15\xa4\x9e\xba\x18k\xf1\x92\xb2~\x14\xcc\n\xc1\xb2\xa4F\x13\x89\xaa</!7\xb5\x03Z\xcd6\xbd\x12\x04\xf6\xd7\x84\xbb0\x14f'
iv = b'l"\xf8uy\xeai\xc2@\xc4\xdbPo\x16w\x0e'

# Derive the key
key_material = ''.join(str(int(x)) for x in s)
key = sha256(key_material.encode()).digest()

# Decrypt the flag
cipher = AES.new(key, AES.MODE_CBC, iv)
flag = unpad(cipher.decrypt(ct), 16)
print("Flag:", flag.decode())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 73
#      70 b = vector(FF, b_entries)
#      72 # Solve the system for s
# ---> 73 s_solution = A.solve_right(b)
#      75 # Verify the solution
#      76 def apply1(F, v):
#
# File ~/mambaforge/envs/sage/lib/python3.10/site-packages/sage/matrix/matrix2.pyx:956, in sage.matrix.matrix2.Matrix.solve_right (build/cythonized/sage/matrix/matrix2.c:16478)()
#     954
#     955         if not self.is_square():
# --> 956             X = self._solve_right_general(C, check=check)
#     957         else:
#     958             try:
#
# File ~/mambaforge/envs/sage/lib/python3.10/site-packages/sage/matrix/matrix2.pyx:1075, in sage.matrix.matrix2.Matrix._solve_right_general (build/cythonized/sage/matrix/matrix2.c:17999)()
#    1073     # Have to check that we actually solved the equation.
#    1074     if self*X != B:
# ...

# %%
# Ensure you run this script in a SageMath environment

from sage.all import *

Ns = [
    ...,
    ...,
    ...,
    ...
]

cts = [
    ...,
    ...,
    ...,
    ...
]

e = 65537

# Approximate Common Divisor Attack using LLL
from sage.all import *

def recover_p(Ns):
    # Number of moduli
    n = len(Ns)

    # We will use the following form to create a polynomial
    # N_i = p * q_i + r_i => N_i - r_i = p * q_i
    # Let's assume r_i is small and can be treated as a perturbation
    PR = PolynomialRing(Zmod(Ns[0]), names=('x',)); (x,) = PR._first_ngens(1)

    # Create a matrix to setup the Lattice
    M = Matrix(ZZ, n + 1)
    
    # Fill the matrix with the relationships
    for i in range(n):
        for j in range(n):
            if i != j:
                M[i, j] = Ns[i] - Ns[j]
                M[i, -1] = 0  # We will use the last column for the constant

    M[-1, -1] = 1  # The constant term to be considered

    # Run LLL to find a short vector
    M = M.LLL()
    
    # We check the first row for a potential candidate for p
    possible_p = abs(M[0, -1])
    if possible_p.bit_length() == 1024:
        return possible_p
    else:
        return None


p = recover_p(Ns)
if p is None:
    print("Failed to recover p.")
else:
    print(f"Recovered p: {p}")

    # Recover q_i and decrypt the flag
    from Crypto.Util.number import inverse, long_to_bytes

    flag = None
    for i in range(len(Ns)):
        N = Ns[i]
        c = cts[i]
        q = N // p
        phi = (p - 1) * (q - 1)
        try:
            d = inverse(e, phi)
        except ValueError:
            continue
        m = pow(c, d, N)
        flag_bytes = long_to_bytes(m)
        if b'flag' in flag_bytes:
            flag = flag_bytes
            break

    if flag:
        print(f"Recovered flag: {flag}")
    else:
        print("Failed to recover the flag.")
# Out:
# Failed to recover p.

# %%
from sage.all import matrix, ZZ
from Crypto.Util.number import inverse

Ns = [
    ...,
    ...,
    ...,
    ...
]

cts = [
    ...,
    ...,
    ...,
    ...
]

# Set up the lattice matrix
B = []
for N in Ns:
    row = [N] + [0] * (len(Ns) - 1)
    B.append(row)

# Append a target row with small random values (r_i)
B.append([r_i for r_i in range(len(Ns))])

# Convert to a Sage matrix
B = matrix(ZZ, B)

# Apply LLL to reduce the lattice
reduced_basis = B.LLL()

# Find the approximate solution for p
p_candidate = None
for vector in reduced_basis:
    # Test each vector to see if it gives a valid p
    # You can verify this by checking if it divides multiple N_i
    candidate = vector[0]
    if candidate == 0:
        continue
    if all(N % candidate == 0 for N in Ns):
        p_candidate = candidate
        break

# Output the potential solution for p
print(f"Possible value of p: {p_candidate}")
# Out:
# Possible value of p: -1
